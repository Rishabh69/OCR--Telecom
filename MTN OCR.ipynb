# %% [markdown]
# The best way I found is to take our new picture, open it in Gimp or Photoshop, and take coordinates for croping it with pillow.

# %% [markdown]
# Image for Name of the candidate

# %%
from PIL import Image
img = Image.open('MTN_form.jpg')

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1240x1754 at 0x7BC3E80>

# %%
import pytesseract

# %%
im= Image.open("MTN_form.jpg")

# %%
im1 = Image.open("Amount1.jpg")

# %%
im1
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=450x60 at 0x8B50048>

# %%
pytesseract.pytesseract.tesseract_cmd = "C:/Program Files (x86)/Tesseract-OCR/tesseract"

# %%
text = pytesseract.image_to_string(im1,lang='eng')

# %%
text
# Out:
# 'DRRNAV\n\nCH\n\nAwuzvsm'

# %%
pyocr
# Out:
# <module 'pyocr' from 'C:\\Users\\rishabh.malhotra\\AppData\\Local\\Continuum\\anaconda3\\lib\\site-packages\\pyocr\\__init__.py'>
